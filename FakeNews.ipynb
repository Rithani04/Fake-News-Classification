# %%
import pandas as pd
import numpy as np
import re
import string
from scipy.sparse import hstack
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# **Loading the Dataset - True and False**

# %%
data_true=pd.read_csv("True.csv")
data_fake=pd.read_csv("Fake.csv")

# %% [markdown]
# **Understanding the Dataset using pandas operations - head, isnull, info**

# %%
data_true.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# 5  WEST PALM BEACH, Fla./WASHINGTON (Reuters) - T...  politicsNews
# 6  WEST PALM BEACH, Fla (Reuters) - President Don...  politicsNews
# 7  The following statements were posted to the ve...  politicsNews
# 8  The following statements were posted to the ve...  politicsNews
# 9  WASHINGTON (Reuters) - Alabama Secretary of St...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017
# 5  December 29, 2017
# 6  December 29, 2017
# 7  December 29, 2017
# 8  December 29, 2017
# 9  December 28, 2017

# %%
data_fake.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# 5  The number of cases of cops brutalizing and ki...    News
# 6  Donald Trump spent a good portion of his day a...    News
# 7  In the wake of yet another court decision that...    News
# 8  Many people have raised the alarm regarding th...    News
# 9  Just when you might have thought we d get a br...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017
# 5  December 25, 2017
# 6  December 23, 2017
# 7  December 23, 2017
# 8  December 22, 2017
# 9  December 21, 2017

# %%
print("true : ",data_true.shape)
print("fake : ",data_fake.shape)
# Out:
# true :  (21417, 4)
# fake :  (23481, 4)

# %%
data_true.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
data_fake.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
data_true.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %% [markdown]
# **Setting the table of true news to be 1 and Fake news to be 0 and concatinating the two datasets**

# %%
data_true['type']=1

# %%
data_fake['type']=0

# %%
data=pd.concat([data_true,data_fake],axis=0)

# %%
data
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 23476  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...   Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 23479  21st Century Wire says Al Jazeera America will...   Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  type
# 0      December 31, 2017      1
# 1      December 29, 2017      1
# 2      December 31, 2017      1
# 3      December 30, 2017      1
# 4      December 29, 2017      1
# ...                   ...   ...
# 23476    January 16, 2016     0
# 23477    January 16, 2016     0
# 23478    January 15, 2016     0
# 23479    January 14, 2016     0
# 23480    January 12, 2016     0
#
# [44898 rows x 5 columns]

# %% [markdown]
# **Shuffling the Dataset**

# %%
data1,data2=train_test_split(data, test_size=0.1, stratify=data['type'], random_state=42)

# %%
data1.shape
# Out:
# (40408, 5)

# %%
data2.shape
# Out:
# (4490, 5)

# %%
data=pd.concat([data1,data2],axis=0)

# %%
data
# Out:
#                                                    title  \
# 4625   U.S. Senate backs Montenegro's membership in NATO
# 11028  Clinton's 'girl power' push wins over women in...
# 12727  CATHOLIC BISHOP OUTRAGED Over Hillary’s ANTI-C...
# 14965  About 30 killed when train derails, catches fi...
# 483     The UNBELIEVABLE Reason Trump Pardoned Arpaio...
# ...                                                  ...
# 13850  Merkel points to grand coalition with Social D...
# 2967    Pres. Obama Just Saved Chelsea Manning On His...
# 16244  BREAKING: HOUSE INTEL LAUNCHES Investigation I...
# 2612    WATCH: Colbert Asks Tapper How CNN Staff Feel...
# 17977  UK border guard arrested in France in drugs, f...
#
#                                                     text          subject  \
# 4625   WASHINGTON (Reuters) - The U.S. Senate on Tues...     politicsNews
# 11028  DES MOINES, Iowa (Reuters) - If Hillary Clinto...     politicsNews
# 12727  Hillary s been using churches across America a...         politics
# 14965  KINSHASA (Reuters) - About 30 people were kill...        worldnews
# 483    If Donald Trump hadn t proven himself to be th...             News
# ...                                                  ...              ...
# 13850  BERLIN (Reuters) - Chancellor Angela Merkel on...        worldnews
# 2967   Presidential commutations and pardons are not ...             News
# 16244  House Intelligence Committee Chairman Devin Nu...  Government News
# 2612   Donald Trump is no fan of CNN. He has repeated...             News
# 17977  PARIS (Reuters) - A British border guard was o...        worldnews
#
#                      date  type
# 4625      March 28, 2017      1
# 11028   January 31, 2016      1
# 12727        Oct 15, 2016     0
# 14965  November 13, 2017      1
# 483       August 28, 2017     0
# ...                   ...   ...
# 13850  November 25, 2017      1
# 2967     January 17, 2017     0
# 16244        Feb 15, 2017     0
# 2612     February 9, 2017     0
# 17977    October 9, 2017      1
#
# [44898 rows x 5 columns]

# %% [markdown]
# **Checking for class imbalance**

# %%
data['type'].value_counts()
# Out:
# type
# 0    23481
# 1    21417
# Name: count, dtype: int64

# %% [markdown]
# **Dropping less significant columns - subject, date**

# %%
data.drop(['subject', 'date'], inplace=True, axis=1)

# %% [markdown]
# **Using python re function to remove unwanted structures from the text**

# %%
def transform_text(text):
    text=text.lower()
    text=re.sub(r'https?://\S+|www\./S+','',text)
    text=re.sub(r'\[.*?\]','',text)
    text=re.sub(r'<.*?>','',text)
    text=re.sub(r'\\W'," ",text)
    text=re.sub(r'\w*\d\w*','',text)
    text=re.sub(r'[%s]' % re.escape(string.punctuation),'',text)
    return text

# %%
data['text']=data['text'].apply(transform_text)
data['title']=data['title'].apply(transform_text)

# %% [markdown]
# **Converting text to vectors using TF-IDF vectorization**

# %%
vectorizer=TfidfVectorizer()
title=vectorizer.fit_transform(data['title'])
text=vectorizer.fit_transform(data['text'])

# %%
combined_features=hstack([title,text])

# %% [markdown]
# **Initializing models - Logistic Regression, LDA, KNeighborsClassifier, DecisionTreeClassifier, GaussianNB**

# %%
models=[]
models.append(('LR', LogisticRegression()))
models.append(('LDR', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('DTree', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))

# %% [markdown]
# **Performing dimensionality reduction using TurncatedSVD**

# %%
from sklearn.decomposition import TruncatedSVD
pca=TruncatedSVD(n_components=100)
dat=pca.fit_transform(combined_features)

# %% [markdown]
# **Using stratified cross validation to run the models and the accuracy is calculated**

# %%
names=[]
results=[]
for name,model in models:
    skf=StratifiedKFold(n_splits=10)
    score=cross_val_score(model, dat, data['type'], cv=skf, scoring='accuracy')
    results.append(score)
    names.append(name)
    msg="%s : %f" % (name, np.mean(score))
    print(msg)
# Out:
# LR : 0.979420
# LDR : 0.977660
# KNN : 0.939463
# DTree : 0.944496
# NB : 0.773575
